# %%
from mirascope import llm
from pydantic import BaseModel
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
import asyncio
import json
import loguru
from loguru import logger
from typing import List, Dict, Any, Optional
from dataclasses import dataclass
from pydantic import BaseModel, Field
from qdrant_client import QdrantClient
from qdrant_client.models import Filter, FieldCondition, MatchValue
import openai
from tqdm import tqdm
import pandas as pd
from datetime import datetime
import os
from loguru import logger
from langsmith import client

# %%
qdrant_client = QdrantClient(
    url="https://c006961b-c63f-469e-b947-33bbfe692e0c.us-east-1-0.aws.cloud.qdrant.io:6333", 
    api_key="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2Nlc3MiOiJtIn0.ruiaT3htpQn4YQY9GTp_UctLaa458w6INYXnVM91JfI",
)
# Out:
# /var/folders/0d/_j5c1nk133xfpm611lvlyw6m0000gn/T/ipykernel_9946/4015246552.py:1: UserWarning: Failed to obtain server version. Unable to check client-server compatibility. Set check_compatibility=False to skip version check.
#   qdrant_client = QdrantClient(

# %%
all_points = qdrant_client.scroll(
    collection_name="Amazon-items-collection-01-hybrid",
    limit=100,
    offset=None,
    with_payload=True,
    with_vectors=False

)
# Out:
# ---------------------------------------------------------------------------
# UnexpectedResponse                        Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 all_points = qdrant_client.scroll(
#       2     collection_name="Amazon-items-collection-01-hybrid",
#       3     limit=100,
#       4     offset=None,
#       5     with_payload=True,
#       6     with_vectors=False
#       7
#       8 )
#
# File ~/Documents/datascience/ai-agents/ai-agents/.venv/lib/python3.12/site-packages/qdrant_client/qdrant_client.py:1459, in QdrantClient.scroll(self, collection_name, scroll_filter, limit, order_by, offset, with_payload, with_vectors, consistency, shard_key_selector, timeout, **kwargs)
#    1417 """Scroll over all (matching) points in the collection.
#    1418
#    1419 This method provides a way to iterate over all stored points with some optional filtering condition.
#    (...)   1455     If next page offset is `None` - there is no more points in the collection to scroll.
#    1456 """
#    1457 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
# -> 1459 return self._client.scroll(
#    1460     collection_name=collection_name,
#    1461     scroll_filter=scroll_filter,
#    1462     limit=limit,
#    1463     order_by=order_by,
#    1464     offset=offset,
#    1465     with_payload=with_payload,
#    1466     with_vectors=with_vectors,
#    1467     consistency=consistency,
#    1468     shard_key_selector=shard_key_selector,
#    1469     timeout=timeout,
#    1470     **kwargs,
#    1471 )
#
# File ~/Documents/datascience/ai-agents/ai-agents/.venv/lib/python3.12/site-packages/qdrant_client/qdrant_remote.py:1719, in QdrantRemote.scroll(self, collection_name, scroll_filter, limit, order_by, offset, with_payload, with_vectors, consistency, shard_key_selector, timeout, **kwargs)
#    1715 if isinstance(with_payload, grpc.WithPayloadSelector):
#    1716     with_payload = GrpcToRest.convert_with_payload_selector(with_payload)
#    1718 scroll_result: Optional[models.ScrollResult] = (
# -> 1719     self.openapi_client.points_api.scroll_points(
#    1720         collection_name=collection_name,
#    1721         consistency=consistency,
#    1722         scroll_request=models.ScrollRequest(
#    1723             filter=scroll_filter,
#    1724             limit=limit,
#    1725             order_by=order_by,
#    1726             offset=offset,
#    1727             with_payload=with_payload,
#    1728             with_vector=with_vectors,
#    1729             shard_key=shard_key_selector,
#    1730         ),
#    1731         timeout=timeout,
#    1732     ).result
#    1733 )
#    1734 assert scroll_result is not None, "Scroll points API returned None result"
#    1736 return scroll_result.points, scroll_result.next_page_offset
#
# File ~/Documents/datascience/ai-agents/ai-agents/.venv/lib/python3.12/site-packages/qdrant_client/http/api/points_api.py:936, in SyncPointsApi.scroll_points(self, collection_name, consistency, timeout, scroll_request)
#     926 def scroll_points(
#     927     self,
#     928     collection_name: str,
#    (...)    931     scroll_request: m.ScrollRequest = None,
#     932 ) -> m.InlineResponse20016:
#     933     """
#     934     Scroll request - paginate over all points which matches given filtering condition
#     935     """
# --> 936     return self._build_for_scroll_points(
#     937         collection_name=collection_name,
#     938         consistency=consistency,
#     939         timeout=timeout,
#     940         scroll_request=scroll_request,
#     941     )
#
# File ~/Documents/datascience/ai-agents/ai-agents/.venv/lib/python3.12/site-packages/qdrant_client/http/api/points_api.py:410, in _PointsApi._build_for_scroll_points(self, collection_name, consistency, timeout, scroll_request)
#     408 if "Content-Type" not in headers:
#     409     headers["Content-Type"] = "application/json"
# --> 410 return self.api_client.request(
#     411     type_=m.InlineResponse20016,
#     412     method="POST",
#     413     url="/collections/{collection_name}/points/scroll",
#     414     headers=headers if headers else None,
#     415     path_params=path_params,
#     416     params=query_params,
#     417     content=body,
#     418 )
#
# File ~/Documents/datascience/ai-agents/ai-agents/.venv/lib/python3.12/site-packages/qdrant_client/http/api_client.py:95, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      93     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      94 request = self._client.build_request(method, url, **kwargs)
# ---> 95 return self.send(request, type_)
#
# File ~/Documents/datascience/ai-agents/ai-agents/.venv/lib/python3.12/site-packages/qdrant_client/http/api_client.py:130, in ApiClient.send(self, request, type_)
#     128     except ValidationError as e:
#     129         raise ResponseHandlingException(e)
# --> 130 raise UnexpectedResponse.for_response(response)
#
# UnexpectedResponse: Unexpected Response: 404 (Not Found)
# Raw response content:
# b'404 page not found\n'

# %%
class Questions(BaseModel):
    question: str
    chunk_ids: list
    answer_example: str
    reasoning: str

@dataclass
class DocumentSummary:
    title: str
    summary: str
    domain: str
    key_topics: list[str]
    total_chunks: int


llm = ChatOpenAI().with_structured_output(Questions)
# Out:
# /Users/neeleshsethi/Documents/datascience/ai-agents/ai-agents/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:1857: UserWarning: Cannot use method='json_schema' with model gpt-3.5-turbo since it doesn't support OpenAI's Structured Output API. You can see supported models here: https://platform.openai.com/docs/guides/structured-outputs#supported-models. To fix this warning, set `method='function_calling'. Overriding to method='function_calling'.
#   warnings.warn(

# %%
SYSTEM_PROMPT = f"""
I am building a RAG application. I have a collection of 50 chunks of text.
The RAG application will act as a shopping assistant that can answer questions about the stock of the products we have available.
I will provide all of the available products to you with indexes of each chunk.
I want you to come up with 30 questions to which the answers could be grounded in the chunk context.
As an output I need you to provide me the list of questions and the indexes of the chunks that could be used to answer them.
Also, provide an example answer to the question given the context of the chunks.
Also, provide the reason why you chose the chunks to answer the questions.
Try to have a mix of questions that could use multipple chunks and questions that could use single chunk.
Also, include 5 questions that can't be answered with the available chunks.

"""

USER_PROMPT = f"""
Here is the list of chunks, each list element is a dictionary with id and text:
{{chunk}}
"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 16
#       1 SYSTEM_PROMPT = f"""
#       2 I am building a RAG application. I have a collection of 50 chunks of text.
#       3 The RAG application will act as a shopping assistant that can answer questions about the stock of the products we have available.
#    (...)     11
#      12 """
#      14 USER_PROMPT = f"""
#      15 Here is the list of chunks, each list element is a dictionary with id and text:
# ---> 16 {[{"id": i, "text": data} for i, data in enumerate(data_to_embed)]}
#      17 """
#
# NameError: name 'data_to_embed' is not defined

# %%
template = ChatPromptTemplate.from_messages(
    
    [

        ('system', SYSTEM_PROMPT),
        ('user', USER_PROMPT)

    ]


)

formatted_template = template.format(
    {})

response = llm.invoke(formatted_template)

# %%
class SyntheticDatasetGenerator:
    def __init__(
            self,
            qdrant_client: str,
            collection_name: str,
            max_retries: int = 3,
            batch_size: int = 10
    ):
        pass
        
    def fetch_all_chunks(self, limit: Optional[int]= None):
        try:
            collection_info = self.qdrant_client.get_collection(self.collection_name)
            total_points = collection_info.points_count
            
            logger.info(f"Total points in collection: {total_points}")
            chunks = []
            offset = None
            fetch_limit = min(limit or total_points, total_points)
            while len(chunks) < fetch_limit:
                 response = self.qdrant_client.scroll(
                    collection_name=self.collection_name,
                    offset=offset,
                    limit=min(100, fetch_limit - len(chunks)),  # Fetch in batches of 100
                    with_payload=True,
                    with_vectors=False  # We don't x vectors for text generation
                )
                 if not response[0]:
                     break
                 
                 for point in response[0]:
                     chunk = {
                        'id': point.id,
                        'text': point.payload.get('text', ''),
                        'metadata': {k: v for k, v in point.payload.items() if k != 'text'}
                         
                     }
                     chunks.append(chunk)
                     offset = response[1]
                 logger.info(F"Successfully fetched len(chunks): chunks")
                 return 
        except Exception as e:
            logger.error(f"Error fetching chunks {str(e)}")



        

    def fetch_all_chunks():
        pass
        
    def generate_document_summary(self,chunks: list[Dict[str,Any]]) -> DocumentSummary:
        logger.info("Generate document summary from chunks")
        pass

    def generate_questions_for_chunk():
   
        pass

    def _call_llm():
        pass

# %%
## Upload the dataset to Comet

# %%
a = {'name': 1, }

# %%
hello()
# Out:
# hello
